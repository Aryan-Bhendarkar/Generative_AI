# %% [markdown]
# ## Search Tool

# %%
from langchain_community. tools import DuckDuckGoSearchRun

search_tool = DuckDuckGoSearchRun()

result = search_tool.invoke("IPL 2026 Leaderboard with the top 5 players as per today (29/05/2026)")
print(result)
# Out:
# 20 hours ago - Get the updated IPL 2026 points table with real-time team standings, wins, losses, and Net Run Rate (NRR). Follow the race to the 2026 Indian Premier League playoffs. 2 days ago - IPL 2026 Points Table: Get latest updated IPL points table, standings and rankings on India Today. Find out ranking, matches, wins, losses and NRR (Net Run Rate) for all the IPL matches played. 18 hours ago - The league stage of IPL 2026 has ... the four playoff spots. RCB finished at the top of the table with 18 points and the best net run rate of +0.783, edging GT and SRH, who also ended with 18 points.... 6 hours ago - IPL 2026 Points Table - Check here for team rankings, points, matches won, net run rate and updated team standings ranking point chart. 1 day ago - The IPL 2026 is in full swing, but who is leading the race for the orange and purple cap? BBC Sport looks at the top run-scorers and wicket-takers in the 19th edition.

# %% [markdown]
# ## Shell Tool

# %%
from langchain_community.tools import ShellTool

shell_tool = ShellTool()

result = shell_tool.invoke("whoami")
print(result)
# Out:
# Executing command:
#  whoami
# victus-aryan\aryan bhendarkar
# c:\Users\ARYAN BHENDARKAR\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_community\tools\shell\tool.py:33: UserWarning: The shell tool has no safeguards by default. Use at your own risk.
#   warnings.warn(
