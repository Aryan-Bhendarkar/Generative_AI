# %% [markdown]
# ## Search Tool

# %%
from langchain_community. tools import DuckDuckGoSearchRun

search_tool = DuckDuckGoSearchRun()

result = search_tool.invoke("IPL 2026 Leaderboard with the top 5 players as per today (29/05/2026)")
print(result)
# Out:
# 12 hours ago ... IPL 2026 Purple Cap Holder: Kagiso Rabada has surged to the top of the IPL 2026 Purple Cap standings with 28 wickets after a stellar performance. 21 Apr 2026 ... IPL 2026 batting stats: Highest strike-rate, average & most sixes · 1. Vaibhav Sooryavanshi (Rajasthan Royals) - 237.30 · 2. Finn Allen (Kolkata Knight Riders) - ... 2 days ago ... Get updated list of IPL 2026 leading run scorers and also find out who has the IPL orange cap right now? Find latest bating stats of IPL 2026. 2 days ago ... 2026 ; 5, K Rabada · Gujarat Titans ; 6, V Kohli · Royal Challengers Bengaluru ; 7, H Klaasen · Sunrisers Hyderabad ; 8, MR Marsh · Lucknow Super Giants ... 2 days ago ... Chennai Super Kings (CSK). Anshul Kamboj - 21; Jamie Overton - 14 ; Sunrisers Hyderabad (SRH). Eshan Malinga - 20; Sakib Hussain - 15 ; Rajasthan Royals (RR).

# %%
print(search_tool.name)
print(search_tool.description)
print(search_tool.args)
# Out:
# duckduckgo_search
# A wrapper around DuckDuckGo Search. Useful for when you need to answer questions about current events. Input should be a search query.
# {'query': {'description': 'search query to look up', 'title': 'Query', 'type': 'string'}}

# %% [markdown]
# ## Shell Tool

# %%
from langchain_community.tools import ShellTool

shell_tool = ShellTool()

result = shell_tool.invoke("whoami")
print(result)
# Out:
# Executing command:
#  whoami
# victus-aryan\aryan bhendarkar
# c:\Users\ARYAN BHENDARKAR\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_community\tools\shell\tool.py:33: UserWarning: The shell tool has no safeguards by default. Use at your own risk.
#   warnings.warn(

# %% [markdown]
# ## Custom Tools

# %%
from langchain_core.tools import tool

@tool
def multiply(a:int, b:int) -> int:
    "Multiply two numbers"
    return a*b

# %%
result = multiply.invoke({"a":2, "b":3})
print(result)
# Out:
# 6

# %%
print(multiply.name)
print(multiply.description)
print(multiply.args)
# Out:
# multiply
# Multiply two numbers
# {'a': {'title': 'A', 'type': 'integer'}, 'b': {'title': 'B', 'type': 'integer'}}
